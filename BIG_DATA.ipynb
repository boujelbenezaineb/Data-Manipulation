# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1) Importer le fichier et charger les données en structure de DataFrame:

# %%
df=pd.read_csv('Salaries.csv')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             Id       EmployeeName  ...         Agency Status
# 0            1     NATHANIEL FORD  ...  San Francisco    NaN
# 1            2       GARY JIMENEZ  ...  San Francisco    NaN
# 2            3     ALBERT PARDINI  ...  San Francisco    NaN
# 3            4  CHRISTOPHER CHONG  ...  San Francisco    NaN
# 4            5    PATRICK GARDNER  ...  San Francisco    NaN
# ...        ...                ...  ...            ...    ...
# 148649  148650      Roy I Tillery  ...  San Francisco     PT
# 148650  148651       Not provided  ...  San Francisco    NaN
# 148651  148652       Not provided  ...  San Francisco    NaN
# 148652  148653       Not provided  ...  San Francisco    NaN
# ...

# %% [markdown]
# 2) Afficher la taille de Dataframe:

# %%
df.shape
# Out:
# (148654, 13)

# %% [markdown]
# 3) Afficher toutes les informations sur les données:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# 4) Afficher uniquement les colonnes(Id, EmpName, JobTitle):

# %%
df[['Id','EmployeeName','JobTitle']]
# Out:
#             Id  ...                                        JobTitle
# 0            1  ...  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            2  ...                 CAPTAIN III (POLICE DEPARTMENT)
# 2            3  ...                 CAPTAIN III (POLICE DEPARTMENT)
# 3            4  ...            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4            5  ...    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...        ...  ...                                             ...
# 148649  148650  ...                                       Custodian
# 148650  148651  ...                                    Not provided
# 148651  148652  ...                                    Not provided
# 148652  148653  ...                                    Not provided
# 148653  148654  ...                      Counselor, Log Cabin Ranch
#
# [148654 rows x 3 columns]

# %% [markdown]
# 5) Afficher la table des 5 premières lignes et les 2 premières colonnes:

# %%
df.iloc[0:5,0:2]
# Out:
#    Id       EmployeeName
# 0   1     NATHANIEL FORD
# 1   2       GARY JIMENEZ
# 2   3     ALBERT PARDINI
# 3   4  CHRISTOPHER CHONG
# 4   5    PATRICK GARDNER

# %% [markdown]
# 6) Afficher les 100 premières lignes de dataframe:

# %%
df.iloc[0:100:,]
# Out:
#      Id       EmployeeName  ...         Agency Status
# 0     1     NATHANIEL FORD  ...  San Francisco    NaN
# 1     2       GARY JIMENEZ  ...  San Francisco    NaN
# 2     3     ALBERT PARDINI  ...  San Francisco    NaN
# 3     4  CHRISTOPHER CHONG  ...  San Francisco    NaN
# 4     5    PATRICK GARDNER  ...  San Francisco    NaN
# ..  ...                ...  ...            ...    ...
# 95   96       MIVIC HIROSE  ...  San Francisco    NaN
# 96   97         SARAH CARY  ...  San Francisco    NaN
# 97   98        KEVIN SMITH  ...  San Francisco    NaN
# 98   99  GREGORY STANGLAND  ...  San Francisco    NaN
# 99  100        SONALI BOSE  ...  San Francisco    NaN
#
# [100 rows x 13 columns]

# %% [markdown]
# 7) Trier les données en ordre croissant suivant les valeurs 'TotalPay':

# %%
df.sort_values(by=['TotalPay'])
# Out:
#             Id           EmployeeName  ...         Agency Status
# 148653  148654              Joe Lopez  ...  San Francisco     PT
# 106745  106746        Tiffany M Rasso  ...  San Francisco    NaN
# 106746  106747       Bertha  Robinson  ...  San Francisco    NaN
# 106747  106748       Kermith T Miller  ...  San Francisco    NaN
# 106748  106749  Rita I Sinasohn-Pharr  ...  San Francisco    NaN
# ...        ...                    ...  ...            ...    ...
# 36159    36160         Gary Altenberg  ...  San Francisco    NaN
# 110532  110533             Amy P Hart  ...  San Francisco     FT
# 110531  110532            David Shinn  ...  San Francisco     PT
# 1            2           GARY JIMENEZ  ...  San Francisco    NaN
# 0            1         NATHANIEL FORD  ...  San Francisco    NaN
#
# [148654 rows x 13 columns]

# %% [markdown]
# 8) Identifier toutes les données manquantes:

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# 9) Remplacer les valeurs manquantes (NaN) par la valeur '0':

# %%
df.replace(to_replace= np.nan , value = 0)
# Out:
#             Id       EmployeeName  ...         Agency Status
# 0            1     NATHANIEL FORD  ...  San Francisco      0
# 1            2       GARY JIMENEZ  ...  San Francisco      0
# 2            3     ALBERT PARDINI  ...  San Francisco      0
# 3            4  CHRISTOPHER CHONG  ...  San Francisco      0
# 4            5    PATRICK GARDNER  ...  San Francisco      0
# ...        ...                ...  ...            ...    ...
# 148649  148650      Roy I Tillery  ...  San Francisco     PT
# 148650  148651       Not provided  ...  San Francisco      0
# 148651  148652       Not provided  ...  San Francisco      0
# 148652  148653       Not provided  ...  San Francisco      0
# 148653  148654          Joe Lopez  ...  San Francisco     PT
#
# [148654 rows x 13 columns]

# %% [markdown]
# 10) Calculer la Moyenne de 'TotalPay':

# %%
mean = df['TotalPay'].mean()
print("La moyenne de TotalPay est:", mean)
# Out:
# La moyenne de TotalPay est: 74768.321971703

# %% [markdown]
# 11) Afficher l'histogramme et la densité de 'TotalPay':

# %% [markdown]
# ***Histogramme de TotalPay:***

# %%
df.hist(column='TotalPay')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f62dcbc31d0>]],
#       dtype=object)

# %% [markdown]
# ***Densité de TotalPay:***

# %%
df['TotalPay'].plot.kde()

# %% [markdown]
# 12) Afficher l'histogramme de 'TotalPay' selon l'année 'Year':

# %%
df.hist(column='TotalPay', by='Year')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f62c032c1d0>,
# ...
#       dtype=object)

# %% [markdown]
# 13) Créer une nouvelle dataframe contenant uniquement les 100000 premières lignes de la dataframe initiale:

# %%
df1= df.iloc[0:100000, :]

# %%
df1
# Out:
#            Id        EmployeeName  ...         Agency Status
# 0           1      NATHANIEL FORD  ...  San Francisco    NaN
# 1           2        GARY JIMENEZ  ...  San Francisco    NaN
# 2           3      ALBERT PARDINI  ...  San Francisco    NaN
# 3           4   CHRISTOPHER CHONG  ...  San Francisco    NaN
# 4           5     PATRICK GARDNER  ...  San Francisco    NaN
# ...       ...                 ...  ...            ...    ...
# 99995   99996       William  Chun  ...  San Francisco    NaN
# 99996   99997  Antoinette L Wells  ...  San Francisco    NaN
# 99997   99998     Richard D Swart  ...  San Francisco    NaN
# 99998   99999         Vivian  Chu  ...  San Francisco    NaN
# 99999  100000    Savitree  Satram  ...  San Francisco    NaN
#
# [100000 rows x 13 columns]

# %% [markdown]
# 14) Convertir le type de 'BasePay' de type 'objet' en type numérique puis afficher la distribution de 'TotalPayBenefits' selon 'BasePay':

# %% [markdown]
# ***Conversion de 'BasePay' de type 'objet' en type 'numeric':***

# %%
df1['BasePay']=pd.to_numeric(df1['BasePay'])
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            Id        EmployeeName  ...         Agency  Status
# 0           1      NATHANIEL FORD  ...  San Francisco     NaN
# 1           2        GARY JIMENEZ  ...  San Francisco     NaN
# 2           3      ALBERT PARDINI  ...  San Francisco     NaN
# 3           4   CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4           5     PATRICK GARDNER  ...  San Francisco     NaN
# ...       ...                 ...  ...            ...     ...
# 99995   99996       William  Chun  ...  San Francisco     NaN
# 99996   99997  Antoinette L Wells  ...  San Francisco     NaN
# ...

# %% [markdown]
# ***Affichage de la distribution de 'TotalPayBenefits' selon 'BasePay':***

# %%
df1.plot.scatter(x='BasePay', y='TotalPayBenefits')

# %% [markdown]
# 15) Enregistrer la nouvelle table des données sous un fichier csv nommé (NewSalaries.csv):

# %%
df1.to_csv('NewSalaries.csv')
